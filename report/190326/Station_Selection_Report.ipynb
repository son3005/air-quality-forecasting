# %% [markdown]
# # 🗺️ Station Selection Report — Bản Đồ Bán Kính 100km
# Mỗi trạm được vẽ một **vòng tròn bán kính 100km**. Các vòng tròn chồng lấp nhau cho thấy trạm nào có thể liên kết Graph.
# - 🔴 **Đỏ:** Cụm Bắc Bộ đề xuất
# - 🔵 **Xanh:** Cụm Nam Bộ đề xuất
# - ⚪ **Xám:** Chưa chọn / Đang cân nhắc
#
# **Nguồn dữ liệu giao thông:**
# - Hà Nội: >8 triệu phương tiện (VnExpress, 01/2024)
# - TP.HCM: >9 triệu phương tiện (Tuổi Trẻ, 09/2023)

# %%
import pandas as pd
import folium

data = [
    (1, 'Hà Nội', 'Cầu Giấy', 21.0323, 105.8007, 'North'),
    (2, 'Hà Nội', 'Thanh Xuân', 20.9947, 105.7998, 'North'),
    (3, 'Hà Nội', 'Tây Hồ', 21.0690, 105.8105, 'North'),
    (4, 'Thanh Hóa', 'Thọ Xuân', 19.9500, 105.5000, 'North'),
    (5, 'Hà Nội', 'Gia Lâm', 21.0535, 106.0071, 'North'),
    (6, 'Hà Nội', 'Ba Vì', 21.0833, 105.3833, 'North'),
    (7, 'TP.HCM', 'Quận 1', 10.7807, 106.6994, 'South'),
    (8, 'TP.HCM', 'Quận 3', 10.7749, 106.6863, 'South'),
    (9, 'TP.HCM', 'Bình Thạnh', 10.8033, 106.6967, 'South'),
    (10, 'TP.HCM', 'Quận 10', 10.7682, 106.6663, 'South'),
    (11, 'TP.HCM', 'Quận 11', 10.7638, 106.6436, 'South'),
    (12, 'TP.HCM', 'Bình Chánh', 10.6954, 106.5913, 'South'),
    (13, 'Đà Nẵng', 'Thanh Khê', 16.0706, 108.1910, 'Drop'),
    (14, 'Đà Nẵng', 'Sơn Trà', 16.0607, 108.2326, 'Drop'),
    (15, 'Đà Nẵng', 'Liên Chiểu', 16.0177, 108.2038, 'Drop'),
    (16, 'Hải Phòng', 'Đồ Sơn', 20.7136, 106.7894, 'North'),
    (17, 'Hải Phòng', 'Hồng Bàng', 20.8607, 106.6790, 'North'),
    (18, 'Cần Thơ', 'Ninh Kiều', 10.0371, 105.7883, 'Drop'),
    (19, 'Cần Thơ', 'Cái Răng', 10.0009, 105.7510, 'Drop'),
    (20, 'Cần Thơ', 'Bình Thủy', 10.0743, 105.7397, 'Drop'),
    (21, 'Khánh Hòa', 'Cam Ranh', 11.9214, 109.1591, 'Drop'),
    (22, 'Khánh Hòa', 'Nha Trang', 12.2451, 109.1943, 'Drop'),
    (23, 'Khánh Hòa', 'Diên Khánh', 12.2549, 109.0933, 'Drop'),
    (24, 'Đồng Nai', 'Biên Hòa', 10.9447, 106.8243, 'South'),
    (25, 'Đồng Nai', 'Long Thành', 10.7891, 106.9503, 'South'),
    (26, 'Đồng Nai', 'Nhơn Trạch', 10.7229, 106.8834, 'South'),
    (27, 'Nam Định', 'TP. Nam Định', 20.4339, 106.1773, 'North'),
    (28, 'Thanh Hóa', 'TP. Thanh Hóa', 19.8000, 105.7667, 'North'),
    (29, 'Nghệ An', 'TP. Vinh', 18.6734, 105.6923, 'Drop'),
    (30, 'Vĩnh Long', 'TP. Vinh Long', 10.2537, 105.9722, 'Drop'),
    (31, 'Trà Vinh', 'TP. Trà Vinh', 9.9472, 106.3423, 'Drop'),
    (32, 'An Giang', 'Rạch Giá', 10.0124, 105.0809, 'Drop')
]

df = pd.DataFrame(data, columns=['ID', 'Province', 'District', 'Lat', 'Lon', 'Cluster'])

# -- Create map --
m = folium.Map(location=[15.5, 107.0], zoom_start=6, tiles='CartoDB positron')

colors = {'North': 'red', 'South': 'blue', 'Drop': 'gray'}
fill_colors = {'North': '#ff4444', 'South': '#4444ff', 'Drop': '#999999'}

for _, row in df.iterrows():
    color = colors[row['Cluster']]
    fill = fill_colors[row['Cluster']]
    
    # Vòng tròn bán kính 100km cho MỖI trạm
    folium.Circle(
        location=(row['Lat'], row['Lon']),
        radius=100000,  # 100km   
        color=color,
        fill=True,
        fill_color=fill,
        fill_opacity=0.08,
        weight=1.5,
        popup=f"Bán kính 100km — Trạm {row['ID']}"
    ).add_to(m)
    
    # Điểm trạm (marker nhỏ)
    folium.CircleMarker(
        location=(row['Lat'], row['Lon']),
        radius=6,
        popup=f"<b>Trạm {row['ID']}</b><br>{row['District']}, {row['Province']}<br>Cluster: {row['Cluster']}",
        color='black',
        weight=1,
        fill=True,
        fill_color=fill,
        fill_opacity=0.9
    ).add_to(m)
    
    # Label trạm
    folium.Marker(
        location=(row['Lat'], row['Lon']),
        icon=folium.DivIcon(html=f'<div style="font-size:9px; font-weight:bold; color:{color}; text-shadow: 1px 1px white;">{row["ID"]}</div>')
    ).add_to(m)

# Legend
legend_html = """
<div style="position: fixed; bottom: 30px; left: 30px; z-index: 1000; 
     background: white; padding: 12px; border-radius: 8px; border: 2px solid #333; font-size: 13px;">
<b>Chú thích</b><br>
🔴 Cụm Bắc Bộ (đề xuất)<br>
🔵 Cụm Nam Bộ (đề xuất)<br>
⚪ Chưa chọn<br>
⭕ Bán kính 100km mỗi trạm
</div>
"""
m.get_root().html.add_child(folium.Element(legend_html))

display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cfc2e6ca39b8d73a0aeb5574b5f8ede9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
# &lt;div style=&quot;position: fixed; bottom: 30px; left: 30px; z-index: 1000;
#      background: white; padding: 12px; border-radius: 8px; border: 2px solid #333; font-size: 13px;&quot;&gt;
# &lt;b&gt;Chú thích&lt;/b&gt;&lt;br&gt;
# 🔴 Cụm Bắc Bộ (đề xuất)&lt;br&gt;
# 🔵 Cụm Nam Bộ (đề xuất)&lt;br&gt;
# ⚪ Chưa chọn&lt;br&gt;
# ⭕ Bán kính 100km mỗi trạm
# &lt;/div&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cfc2e6ca39b8d73a0aeb5574b5f8ede9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cfc2e6ca39b8d73a0aeb5574b5f8ede9 = L.map(
#                 &quot;map_cfc2e6ca39b8d73a0aeb5574b5f8ede9&quot;,
#                 {
#                     center: [15.5, 107.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8d37ebbab386032475729a6e1ba04c30 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8d37ebbab386032475729a6e1ba04c30.addTo(map_cfc2e6ca39b8d73a0aeb5574b5f8ede9);
#
#
#             var circle_714592fb97dd4660db4cf1b3ec08a45d = L.circle(
#                 [21.0323, 105.8007],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ff4444&quot;, &quot;fillOpacity&quot;: 0.08, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 75000, &quot;stroke&quot;: true, &quot;weight&quot;: 1.5}
#             ).addTo(map_cfc2e6ca39b8d73a0aeb5574b5f8ede9);
#
#
#         var popup_8f056f46f17129186ec1897bbbf0eaa5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_42bb287368183a16ae8362ad76f2041b = $(`&lt;div id=&quot;html_42bb287368183a16ae8362ad76f2041b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bán kính 100km — Trạm 1&lt;/div&gt;`)[0];
#                 popup_8f056f46f17129186ec1897bbbf0eaa5.setContent(html_42bb287368183a16ae8362ad76f2041b);
#
#
#
#         circle_714592fb97dd4660db4cf1b3ec08a45d.bindPopup(popup_8f056f46f17129186ec1897bbbf0eaa5)
#         ;
#
#
#
#
#             var circle_marker_e4a4b5289c6c5bc462c1bb689d2fdcc8 = L.circleMarker(
#                 [21.0323, 105.8007],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ff4444&quot;, &quot;fillOpacity&quot;: 0.9, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_cfc2e6ca39b8d73a0aeb5574b5f8ede9);
#
#
#         var popup_b16598cac6113176d1d521e66e7ccd1d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8f7b8a41897f7621f95102724062a111 = $(`&lt;div id=&quot;html_8f7b8a41897f7621f95102724062a111&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Trạm 1&lt;/b&gt;&lt;br&gt;Cầu Giấy, Hà Nội&lt;br&gt;Cluster: North&lt;/div&gt;`)[0];
#                 popup_b16598cac6113176d1d521e66e7ccd1d.setContent(html_8f7b8a41897f7621f95102724062a111);
#
#
#
#         circle_marker_e4a4b5289c6c5bc462c1bb689d2fdcc8.bindPopup(popup_b16598cac6113176d1d521e66e7ccd1d)
#         ;
#
#
#
#
#             var marker_21432e7cf6ef4a7cbc647f84b2cd6b4d = L.marker(
#                 [21.0323, 105.8007],
#                 {
# }
#             ).addTo(map_cfc2e6ca39b8d73a0aeb5574b5f8ede9);
#
#
#             var div_icon_11ce1bc52c09aacbb9875f3d5a23a33b = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size:9px; font-weight:bold; color:red; text-shadow: 1px 1px white;\&quot;\u003e1\u003c/div\u003e&quot;,
#   &quot;className&quot;: &quot;empty&quot;,
# });
#
#
#                 marker_21432e7cf6ef4a7cbc647f84b2cd6b4d.setIcon(div_icon_11ce1bc52c09aacbb9875f3d5a23a33b);
#
#
#             var circle_d32e9d0a61342fbbef68342372a4bde2 = L.circle(
#                 [20.9947, 105.7998],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dash

# %% [markdown]
# ## Hướng Dẫn Đọc Bản Đồ
# - **Zoom vào từng vùng** để xem các vòng tròn 100km chồng lấp.
# - Trạm nào có vòng tròn **chồng lấp nhiều** với các trạm khác → Liên kết Graph mạnh.
# - Trạm nào **cô lập** (vòng tròn không chạm ai) → Ứng cử viên bị loại.
# - Tại cụm HCM: Các vòng xanh chồng kín lên nhau → Xác nhận data trùng lặp (r=0.999).
# - Tại cụm Bắc: Vòng đỏ phủ đều → Mỗi trạm đóng góp thông tin riêng biệt.
#
# > 💡 **Tip:** Click vào vòng tròn hoặc điểm để xem thông tin trạm.
